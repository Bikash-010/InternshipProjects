# %% [markdown]
# # **FINANCIAL MARKET NEWS**

# %% [markdown]
# -------------

# %% [markdown]
# ## **Objective**

# %% [markdown]
#   By studying it the individual or the orginasation can stay ahead in a dynamic environment,make strategic financial decission and better manage their investment.

# %% [markdown]
# ## **Data Source**

# %% [markdown]
# Yahoo Finance,Blookmberg adn Reuters,Economicdata providers,Government Reports,Company Fillings,Financial terminals

# %% [markdown]
# ## **Import Library**

# %%
import panda as pd
import numpy as np

# %% [markdown]
# ## **Import Data**

# %%
df=pd.read_csv(r'https://github.com/YBIFoundation/Dataset/raw/main/Financial%20Market%20News.csv',encoding="ISO-8859-1")
df.head()
df.info()
df.shape()
df.columns()

# %% [markdown]
# ## **Describe Data**

# %%
''.join(str(x)for x in df.iloc[1,2:27])

# %% [markdown]
# ## **Data Visualization**

# %%
df.index()
len(df.index)
news=[]
type(news)

# %% [markdown]
# ## **Data Preprocessing**

# %%
news[0]
x=news
type(x)

# %% [markdown]
# ## **Define Target Variable (y) and Feature Variables (X)**

# %%
from sklearn.feature_extraction.text import countervector size
cv=countervectorsize (lowercase=True,ngram_range=(1,11))
x=cv.fit_transform(x)
x.shape
y=df['label']
y.shape

# %% [markdown]
# ## **Train Test Split**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,stratify=y,random_state=2529)
from sklearn.ensemble import Random forest classifier

# %% [markdown]
# ## **Modeling**

# %%
rf=Randomforest clasifier(n_estimate=200)
rf.fit(x_train,y_train)
Random forest classifier(n_estimation=200)
y_pred=rf.predict(x_test)

# %% [markdown]
# ## **Model Evaluation**

# %%
from sklearn.metrics import classifier_report,confusion_matrix,accuracy_score
confusion_matrix(y_test,y_pred)

# %% [markdown]
# ## **Prediction**

# %%
print(classifier_report(y_test,y_pred))

# %% [markdown]
# ## **Explaination**

# %% [markdown]
# Studying financial market news helps you make informed investment decissions,understand market sentiment,manage risks,identify new opportunities,and stay updated on economic and regulatory changes.
# Reliable resource for this information include financial news website like bloomberg and Reuters,stock market data platforms like yahoo finance and economic data providers like the federal reserve.These sources provide the necessary insights to navigate the financial markets effectively.
