# %% [markdown]
# # **Movie Recomendation System**

# %% [markdown]
# -------------

# %% [markdown]
# ## **Objective**

# %% [markdown]
# To suggest a movie to users that align with their tastes and preferences.This is achieved by analyzing patterns in users behaviour,such as movie ratings,watch history,and the similarities between movie and users.

# %% [markdown]
# ## **Data Source**

# %% [markdown]
# Movie lens,IMDB Datasets,OMDb API,Kaggle Datasets

# %% [markdown]
# ## **Import Library**

# %%
import panda as pd
import numpy as np

# %% [markdown]
# ## **Import Data**

# %%
df=pd.read_csv(r"https://github.com/YBIFoundation/Dataset/raw/main/Movies%20Recommendation.csv")
df.head()
df.info()
df.shape()
df.columns()

# %% [markdown]
# ## **Describe Data**

# %%
movie_id,title,genre,description
101,The Matrix,Action,Sci-Fi,"A hacker discovers a dystopian reality."
102,Inception,Action,Sci-Fi,"A thief who enters dreams to steal secrets."
103,The Shawshank Redemption,Drama,"A man wrongly convicted of murder forms a friendship in prison."
104,The Dark Knight,Action,Crime,"Batman faces off against the Joker."
105,Pulp Fiction,Crime,Drama,"The lives of two mob hitmen, a boxer, and others intertwine."

# %% [markdown]
# ## **Data Visualization**

# %%
df_featuredf[["movie-genre","movie-keywords","movie-tagline","movie-cast","movie-director"]].fillna('')
df_features.shape
df_feature
x=df_feature['movie_genre']+''+df_feature['movie_keywors']+''+df_feature['movie_tagline']+''+df_feature['movie-cast']+''+df_feature['movie director']
x
x.shape

# %% [markdown]
# ## **Data Preprocessing**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf=tfidf vectorsizer()
x=tfidf.fit_transform(x)
x.shape
print(x)

# %% [markdown]
# ## **Define Target Variable (y) and Feature Variables (X)**

# %%
df.columns
x=df[['genere','cast','director']]
y=user_movie_ratings['rating']
model.fit(x,y)

# %% [markdown]
# ## **Train Test Split**

# %%
from sklearn.metrics.pairwise import cosize_similarity
similarity_score=cosine_similarity(x)
similarity_score
similarity_score.shape

# %% [markdown]
# ## **Modeling**

# %%
favourite_movie_name=input("enter your favourite movie name")
all_movie_title_list=df["movie_title"].tolist()
import difflib
movie_recomendation=difflib.get_close_matrics(favourite_movie name,all_movies_title_list)
 print(movie recomendation)
close_match=movie_recomendation(0)
 print(close_match)
index_of_close_match=df[df.movie_title==close match]
 print(inderx_of_close_match_movie)
Recomendation_score=list(enumerates(similarity_score[index_of_close_match_movie]))
print(Recomendation_score)
len(Recomendation_score)

# %% [markdown]
# ## **Model Evaluation**

# %%
sorted_similar_movie=sorted(Recomendation_score.key=lambda.x:x[1],revenue=True)
print(sorted_similar_movies)
print('top30 movies suggested for you:\n')
i=1
for movie in sorted_similar_movies
index=movie[0]
title_from_index=df[df.index==index]['movies_title'].value[0]

if(i<31):
    print(i,'.',title_from_index)
i+=1

# %% [markdown]
# ## **Prediction**

# %%
movie_name=input("enter your favourite movie name:")
list_of all titles=df['movie_title'].to list()
find_close_match=difflib.get_close_matches(moie_name,list_of_all_titles)
close_match=find_close_match(0)
index_of_movie=df[df.movie_title=close_match]['movie_id'].values[0]
Recomendation_score=list(enumerates[similarirt_score,index_of_movie])
sorted simmilar movies=sorted(Recomendation_score,key_lambda x:x[1],reverse=True)
print('top10 movies suggested for you:\n')
i=1
for movies in sorted_similar_movies:
    index=movie[0]
    title_from_index=df[df.movie_id==index]["movie title"].values
    if(i<11):
        print(i,'.',title_from_index)
        i+=1

# %% [markdown]
# ## **Explaination**

# %% [markdown]
# The main goal is to enhance the user experience by helping them discover new and relevant movies,thereby incresing user retention and satisfaction on the platform where the recomendation system is implemented.
